# %% [markdown]
# # Matched pair AB Test
#
# In this notebook we will identify 2 control units for each of the 10 treatment units. We are given 2 files:
#
# newproductcontroldata.csv
#
# grapeproducttreatmentstores.csv
#
# The treatment units are stored in grapeproducttreatmentstores.csv

# %%
#import necessary packages:

import pandas as pd
import numpy as np
from scipy import spatial

# %% [markdown]
# Read the files to data frames:

# %%
treatment_df = pd.read_csv("./downloads/grapeproducttreatmentstores.csv")
control_df = pd.read_csv("./downloads/newproductcontroldata.csv")

# %% [markdown]
# display sample rows:

# %%
treatment_df
# Out:
#    Store ID           City State  Zip Code  Category Sales  Product Count  \
# 0       332        La Mesa    CA     91942        56792.96              5
# 1       944       Palmdale    CA     93551           41.50              1
# 2      1181  Lake Elsinore    CA     92532         1514.11              4
# 3      2696  Redondo Beach    CA     90278         2006.88              4
# 4      2717  Thousand Oaks    CA     91320           80.04              2
# 5      3060  San Francisco    CA     94111        26467.99              7
# 6      5019           Napa    CA     94558        16744.96              5
# 7      5051    Simi Valley    CA     93065         1378.85              3
# 8      5395    Los Angeles    CA     90079         5669.56              5
# 9      5834        Fremont    CA     94539        19064.48              6
#
#     Size
# 0  Large
# 1  Large
# 2  Large
# 3  Large
# 4  Large
# 5  Large
# 6  Large
# 7  Large
# 8  Large
# 9  Large

# %%
control_df.head()
# Out:
#      Store ID         City State  Zip Code  Category Sales  Product Count  \
# 103       104  Bakersfield    CA     93311          666.18              5
# 104       105  Canoga Park    CA     91303          868.80              3
# 105       106        Colma    CA     94014        11682.08              5
# 106       107   Costa Mesa    CA     92626        58509.72              5
# 107       108       Dublin    CA     94568         4601.87              4
#
#       Size
# 103  Large
# 104  Large
# 105  Large
# 106  Large
# 107  Large

# %% [markdown]
# We do not need City, Zip, Size columns. Also we do not need any other state values except the state of CA in treatment_df. We identified State, Product Count and Category Sales as control variables. Since the treatment units all have CA as the state we are dropping that.

# %%
treatment_df = treatment_df[treatment_df['State'] == 'CA']
control_df = control_df[control_df['State'] == 'CA']

# %%
treatment_df
# Out:
#    Store ID           City State  Zip Code  Category Sales  Product Count  \
# 0       332        La Mesa    CA     91942        56792.96              5
# 1       944       Palmdale    CA     93551           41.50              1
# 2      1181  Lake Elsinore    CA     92532         1514.11              4
# 3      2696  Redondo Beach    CA     90278         2006.88              4
# 4      2717  Thousand Oaks    CA     91320           80.04              2
# 5      3060  San Francisco    CA     94111        26467.99              7
# 6      5019           Napa    CA     94558        16744.96              5
# 7      5051    Simi Valley    CA     93065         1378.85              3
# 8      5395    Los Angeles    CA     90079         5669.56              5
# 9      5834        Fremont    CA     94539        19064.48              6
#
#     Size
# 0  Large
# 1  Large
# 2  Large
# 3  Large
# 4  Large
# 5  Large
# 6  Large
# 7  Large
# 8  Large
# 9  Large

# %%
control_df.shape
# Out:
# (913, 7)

# %%
treatment_df.shape
# Out:
# (10, 7)

# %% [markdown]
# Dropping unnecessary columns

# %%
treatment_product_count = treatment_df['Product Count']
treatment_category_sales = treatment_df['Category Sales']
treatment_category_store_ID = treatment_df['Store ID']

control_product_count = control_df['Product Count']
control_category_sales = control_df['Category Sales']
control_category_store_ID = control_df['Store ID']

#DO NOT SCALE. As this is NOT giving correct results

#treatment_product_count = (treatment_product_count - treatment_product_count.min())/(treatment_product_count.max() - treatment_product_count.min())
#treatment_category_sales = (treatment_category_sales - treatment_category_sales.min())/(treatment_category_sales.max() - treatment_category_sales.min())

#control_product_count = (control_product_count - control_product_count.min())/(control_product_count.max() - control_product_count.min())
#control_category_sales = (control_category_sales - control_category_sales.min())/(control_category_sales.max() - control_category_sales.min())

# %%
len(treatment_product_count)
# Out:
# 10

# %%
len(control_product_count)
# Out:
# 913

# %%
tree = spatial.KDTree(list(zip(control_product_count, control_category_sales)))
tree.data
#list(zip(treatment_product_count, treatment_category_sales))
# Out:
# array([[5.000000e+00, 6.661800e+02],
#        [3.000000e+00, 8.688000e+02],
#        [5.000000e+00, 1.168208e+04],
#        ...,
#        [6.000000e+00, 8.387900e+03],
#        [5.000000e+00, 2.537506e+04],
#        [5.000000e+00, 3.799680e+03]])

# %%
pts = list(zip(treatment_product_count, treatment_category_sales))
pts
# Out:
# [(5, 56792.96),
#  (1, 41.5),
#  (4, 1514.11),
#  (4, 2006.88),
#  (2, 80.04),
#  (7, 26467.99),
#  (5, 16744.96),
#  (3, 1378.85),
#  (5, 5669.56),
#  (6, 19064.48)]

# %%
tree.query(pts, k=2,p=2)[1]
# Out:
# array([[ 55, 781],
#        [201, 674],
#        [241, 359],
#        [390,  28],
#        [411, 513],
#        [494, 787],
#        [681, 672],
#        [713, 239],
#        [798, 484],
#        [832, 605]])

# %%
k = 0
for i,j,l in tree.query(pts, k=3)[1]:
    #print(i,j)
    print(treatment_df.iloc[k])
    k += 1
    print(control_df[control_df['Store ID'] == list(control_category_store_ID)[j]])
    print(control_df[control_df['Store ID'] == list(control_category_store_ID)[l]])    
    print("\n\n")
    #print(list(control_category_store_ID)[i],list(control_category_store_ID)[j])
# Out:
# Store ID              332
# City              La Mesa
# State                  CA
# Zip Code            91942
# Category Sales      56793
# Product Count           5
# Size                Large
# Name: 0, dtype: object
#       Store ID     City State  Zip Code  Category Sales  Product Count   Size
# 5377      5378  Anaheim    CA     92807        56371.04              6  Small
#       Store ID             City State  Zip Code  Category Sales  \
# 3955      3956  North Highlands    CA     95660        57243.36
#
#       Product Count    Size
# 3955              5  Medium
#
#
#
# Store ID               944
# City              Palmdale
# State                   CA
# Zip Code             93551
# Category Sales        41.5
# Product Count            1
# Size                 Large
# Name: 1, dtype: object
#       Store ID  City State  Zip Code  Category Sales  Product Count   Size
# 5011      5012  Lodi    CA     95242           40.58              2  Large
#       Store ID      City State  Zip Code  Category Sales  Product Count   Size
# 5621      5622  El Monte    CA     91731           39.56              3  Large
#
#
#
# Store ID                   1181
# City              Lake Elsinore
# State                        CA
# Zip Code                  92532
# Category Sales          1514.11
# Product Count                 4
# Size                      Large
# Name: 2, dtype: object
#       Store ID    City State  Zip Code  Category Sales  Product Count   Size
# 2664      2665  Fresno    CA     93720         1516.13              4  Large
#       Store ID           City State  Zip Code  Category Sales  Product Count  \
# 4785      4786  National City    CA     91950          1526.4              4
#
#        Size
# 4785  Large
#
#
#
# Store ID                   2696
# City              Redondo Beach
# State                        CA
# Zip Code                  90278
# Category Sales          2006.88
# Product Count                 4
# Size                      Large
# Name: 3, dtype: object
#      Store ID   City State  Zip Code  Category Sales  Product Count   Size
# 212       213  Indio    CA     92203         2019.07              5  Large
#      Store ID         City State  Zip Code  Category Sales  Product Count  \
# 115       116  Palm Desert    CA     92260         1991.55              3
#
#       Size
# 115  Large
#
#
#
# Store ID                   2717
# City              Thousand Oaks
# State                        CA
# Zip Code                  91320
# Category Sales            80.04
# Product Count                 2
# Size                      Large
# Name: 4, dtype: object
#       Store ID   City State  Zip Code  Category Sales  Product Count   Size
# 3285      3286  Chino    CA     91710           79.12              3  Large
#       Store ID     City State  Zip Code  Category Sales  Product Count   Size
# 2720      2721  Visalia    CA     93277            76.8              3  Large
#
#
#
# Store ID                   3060
# City              San Francisco
# State                        CA
# Zip Code                  94111
# Category Sales            26468
# Product Count                 7
# Size                      Large
# Name: 5, dtype: object
#       Store ID      City State  Zip Code  Category Sales  Product Count  \
# 5383      5384  Torrance    CA     90505        26467.32              6
#
#         Size
# 5383  Medium
#       Store ID       City State  Zip Code  Category Sales  Product Count  \
# 1172      1173  Livermore    CA     94551        26504.88              6
#
#        Size
# 1172  Large
#
#
#
# Store ID           5019
# City               Napa
# State                CA
# Zip Code          94558
# Category Sales    16745
# Product Count         5
# Size              Large
# Name: 6, dtype: object
#       Store ID       City State  Zip Code  Category Sales  Product Count  \
# 5009      5010  Lancaster    CA     93534         16800.0              6
#
#        Size
# 5009  Large
#       Store ID          City State  Zip Code  Category Sales  Product Count  \
# 4983      4984  Baldwin Park    CA     91706        16665.38              6
#
#        Size
# 4983  Large
#
#
#
# Store ID                 5051
# City              Simi Valley
# State                      CA
# Zip Code                93065
# Category Sales        1378.85
# Product Count               3
# Size                    Large
# Name: 7, dtype: object
#       Store ID         City State  Zip Code  Category Sales  Product Count  \
# 1178      1179  Simi Valley    CA     93065         1400.56              4
#
#        Size
# 1178  Large
#       Store ID       City State  Zip Code  Category Sales  Product Count  \
# 5850      5851  San Diego    CA     92123         1400.56              4
#
#        Size
# 5850  Small
#
#
#
# Store ID                 5395
# City              Los Angeles
# State                      CA
# Zip Code                90079
# Category Sales        5669.56
# Product Count               5
# Size                    Large
# Name: 8, dtype: object
#       Store ID           City State  Zip Code  Category Sales  Product Count  \
# 3049      3050  San Francisco    CA     94108         5680.32              5
#
#        Size
# 3049  Large
#      Store ID      City State  Zip Code  Category Sales  Product Count   Size
# 213       214  Murrieta    CA     92562         5685.28              6  Large
#
#
#
# Store ID             5834
# City              Fremont
# State                  CA
# Zip Code            94539
# Category Sales    19064.5
# Product Count           6
# Size                Large
# Name: 9, dtype: object
#       Store ID      City State  Zip Code  Category Sales  Product Count   Size
# 3953      3954  Cerritos    CA     90703        19053.41              6  Large
#       Store ID        City State  Zip Code  Category Sales  Product Count  \
# 5826      5827  Sacramento    CA     95834        19008.96              6
#
#        Size
# 5826  Large
